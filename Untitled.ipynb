# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/alishbahiqbal/Desktop/c2v_pytorch/Code2vec_Pytorch_pipeline/csvs/q1_BIG_marks.csv')
df
# Out:
#             K213261  10
# 0           K214693   5
# 1           K214878  10
# 2           K213160   6
# 3           K213223  10
# 4           K214657   0
# ..              ...  ..
# 657  K201889 copy 2  10
# 658  K214578 copy 2  10
# 659  K213296 copy 2   7
# 660  K213459 copy 2   8
# 661  K214601 copy 2   2
#
# [662 rows x 2 columns]

# %%
#K180149
file = 'K180149.c'
# file = '/Users/alishbahiqbal/Desktop/c2v_pytorch/Code2vec_Pytorch_pipeline/data/q1/K180149.c'

# %%
df1 = df.loc[df['FileName']+ '.c' == file]

# %%
df1['Marks'].values[0]
# Out:
# 3

# %%
files = '/Users/alishbahiqbal/Desktop/c2v_pytorch/Code2vec_Pytorch_pipeline/data/q1/K213206.c'

# %%
from os import listdir
from os.path import isfile, join
mypath= '/Users/alishbahiqbal/Desktop/c2v_pytorch/Code2vec_Pytorch_pipeline/data/q1_BIG'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/lp/8qls9f8d5831w65zw_yh3xp80000gn/T/ipykernel_97952/32546335.py in <module>
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
df1 = df.loc[df['FileName']+ '.c' == files.split('/')[-1]]

# %%
for f in df['FileName']:
#     if f.split('/')[-1] + '.c' not in onlyfiles:
    print(f)
#         l = df.loc[ df['FileName'] == f ]
# Out:
# K213261
# K214693
# K214878
# K213160
# K213223
# K214657
# K213380
# K214920
# K213370
# K214901
# K213286
# K214933
# K214944
# K213181
# K213444
# K214508
# K214581
# K213155
# K213376
# K213165
# K214536
# K213286
# K213348
# K213303
# K214835
# K214675
# K213274
# K214836
# K214855
# K213307
# K214541
# K214664
# K213170
# K213306
# K214842
# K213311
# K213374
# K213326
# K214868
# K213339
# K214867
# K213309
# K213436
# K213188
# K214866
# K214929
# K213291
# K201903
# K214655
# K213273
# K213383
# K214834
# K213240
# K213335
# K213249
# K213248
# K213177
# K214866
# K214600
# K214827
# K213154
# K213154
# K213329
# K213211
# K214588
# K213390
# K213421
# K214620
# K213385
# K214680
# K214547
# K213211
# K214833
# K214678
# K214676
# K214523
# K213211
# K213450
# K214946
# K213385
# K214548
# K214680
# K214692
# K213392
# K213278
# K213425
# K214931
# K214667
# K214571
# K213288
# K213206
# K213297
# K214614
# K214942
# K213388
# K213242
# K213239
# K214585
# K214553
# K213434
# ...

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir('/Users/alishbahiqbal/Desktop/c2v_pytorch/Code2vec_Pytorch_pipeline/data/q1_BIG') if isfile(join('/Users/alishbahiqbal/Desktop/c2v_pytorch/Code2vec_Pytorch_pipeline/data/q1_BIG', f))]

df = pd.read_csv('/Users/alishbahiqbal/Desktop/c2v_pytorch/Code2vec_Pytorch_pipeline/csvs/q1_BIG_marks.csv')
df
onlyfiles.remove('.DS_Store')

for f in onlyfiles:
    df1 = df.loc[df['FileName']+ '.c' == f.split('/')[-1]] 
    print(f)
#     marks = df1['Marks']
#     print(int(marks))
# Out:
# K214842 copy 2.c
# K213206.c
# K213326 copy 3.c
# K201715 copy 3.c
# K214588 copy 5.c
# K213410 copy.c
# K213181 copy 4.c
# K214945 copy 3.c
# K214548 copy 2.c
# K214944 copy 3.c
# K213241 copy.c
# K214675 copy 5.c
# K214577 copy.c
# K213329.c
# K214547 copy 3.c
# K213456.c
# K213374 copy 4.c
# K201889.c
# K213273 copy 5.c
# K214898.c
# K213329 copy 2.c
# K213268 copy 2.c
# K213155 copy 5.c
# K213333 copy 5.c
# K214518 copy.c
# K214601.c
# K214766 copy 2.c
# K214500 copy 2.c
# K213253 copy.c
# K213353 copy.c
# K214931.c
# K213348.c
# K214541.c
# K214553 copy 5.c
# K213437.c
# K213330 copy.c
# K214898 copy 2.c
# K213959 copy 2.c
# K213280.c
# K214858 copy 5.c
# K213001 copy 3.c
# K214592 copy 2.c
# K213418.c
# K213570 copy 4.c
# K213218 copy.c
# K213380.c
# K214577 copy 2.c
# K214553 copy.c
# K213243 copy 4.c
# K213242 copy 4.c
# K213434 copy.c
# K214505.c
# K214928 copy 4.c
# K213206 copy.c
# K213184.c
# K214929 copy 4.c
# K213248.c
# K213170 copy 2.c
# K213306 copy.c
# ...
