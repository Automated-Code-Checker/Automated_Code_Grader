# %%
from tkinter import *
from tkinter import ttk
import tkinter.font as tkFont
from tkinter import filedialog
import random
import pandas as pd
import csv
import os

# %%
def get_model(selection):
    global model_number
    data = pd.read_csv("/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/Questions.csv")
    df2=data[data['Question']==clicked.get()]['ID']
    model_number = df2.values[0]
    
def read_questionFile():
    questions = []
    question_data = pd.read_csv("/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/Questions.csv")
    question = question_data["Question"]
    for q in question:
        questions.append(q)
    return questions

def read_folder():
    global folderpath , foldername
    root.foldername = filedialog.askdirectory(initialdir="/Users/unaissiddiqui/Desktop/Fyp", title="Select A Folder")
    head_tail = os.path.split(root.foldername)
    ButtonFolder['text'] = head_tail[1]
    folderpath = root.foldername
    foldername = head_tail[1]

def read_file():
    global filepath, filename
    root.filename = filedialog.askopenfilename(initialdir="/Users/unaissiddiqui/Desktop/Fyp", title="Select A File")
    head_tail = os.path.split(root.filename)
    ButtonFile['text'] = head_tail[1]
    filepath = root.filename
    filename = head_tail[1]
    
def ran_number():
    random_number = random.randint(1000000,9999999)
    data = pd.read_csv("/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/Questions.csv")
    if random_number in data.values:
        random_number = random.randint(1000000,9999999)
    else:
        return random_number

def train():
    Question_csv_list = []
    random_number = ran_number()
    Question_csv_list.append(random_number)
    Question_csv_list.append(question.get())
    f = open('/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/Questions.csv', 'a')
    writer = csv.writer(f)
    writer.writerow(Question_csv_list)
    f.close()
    os.chdir("/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader")
    os.system("rm -R data")
    os.system("mkdir data")
    os.system("rm -R Marks_csv")
    os.system("mkdir Marks_csv")
    os.chdir("/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/data")
    os.system("cp -R "+ folderpath + " "+foldername)
    os.system("mv "+ foldername+" Codes")
    os.chdir("/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/Marks_csv")
    os.system("cp "+ filepath + " "+filename)
    os.system("mv "+ filename+" Data_Marks.csv")
    os.chdir("/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader")
    os.system("./preprocess.sh 0 /Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/data/Codes Codes_embeddings")
    os.system("python train.py "+str(random_number))
    ButtonTrain['text'] = "Trained"

def test():
    os.chdir("/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader")
    os.system("rm -R data")
    os.system("mkdir data")
    os.chdir("/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/data")
    os.system("cp -R "+ folderpath + " "+foldername)
    os.system("mv "+ foldername+" Codes")
    os.chdir("/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader")
    os.system("./preprocess_test.sh 1 /Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/data/Codes Codes_embeddings")
    data = pd.read_csv("/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/Values.csv")
    values_vocab_size = data[data['ID']==dataset_name]['word2idx'].values[0]
    paths_vocab_size = data[data['ID']==dataset_name]['path2idx'].values[0]
    labels_num = data[data['ID']==dataset_name]['target2idx'].values[0]
    cmd = f"python test.py {str(model_number)} {values_vocab_size} {paths_vocab_size} {labels_num}"
    os.system(cmd)
    ButtonTest['text'] = "Graded"
    
def change_train():
    ButtonTrain['text'] = "Training.."
    ButtonTrain.after(400,train)

def change_test():
    ButtonTest['text'] = "Grading.."
    ButtonTest.after(400,test)

def back_train():
    ButtonFolder.place_forget()
    ButtonFile.place_forget()
    ButtonTrain.place_forget()
    ButtonBack.place_forget()
    TitleLabel.place_forget()
    questionLabel.place_forget()
    FolderLabel.place_forget()
    FileLabel.place_forget()
    root_f()
    
def back_test():
    ButtonFolder.place_forget()
    QuestionLabel.place_forget()
    FolderLabel.place_forget()
    ButtonFolder.place_forget()
    ButtonBack.place_forget()
    ButtonTest.place_forget()
    root_f()
    
def kill_train():
    TitleLabel.place_forget()
    Button_test_frame.place_forget()
    Button_train_frame.place_forget()
    TitleLabelS.place_forget()
    train_f()
    
def kill_test():
    TitleLabel.place_forget()
    Button_test_frame.place_forget()
    Button_train_frame.place_forget()
    TitleLabelS.place_forget()
    test_f()

# %%
def train_f():
    global ButtonFolder, ButtonFile, ButtonTrain, ButtonBack, TitleLabel, questionLabel, FolderLabel, FileLabel, question
    root.geometry("900x500")

    #Title Label
    TitleLabel = Label(root,text="Train Model")
    ft = tkFont.Font(family='Copperplate',size=22)
    TitleLabel["font"] = ft
    TitleLabel.place(x=350,y=15,width=200,height=35)

    #Input Question
    questionLabel = Label(root,text='Enter Question : ')
    questionLabel.place(x=0,y=68,width=110,height=40)
    question = Entry(root)
    question.place(x=110,y=70,width=770,height=37)

    #Select Folder
    FolderLabel = Label(root,text='Select Folder :')
    FolderLabel.place(x=0,y=130,width=95,height=40)
    ft = tkFont.Font(family='Lucida Sans',size=13)
    FolderLabel["font"] = ft
    ButtonFolder = Button(root,text="Upload Folder",command=read_folder)
    ButtonFolder.place(x=120,y=137,width=200,height=30)

    #Select File
    FileLabel = Label(root,text='Select Marks File :')
    FileLabel.place(x=2,y=195,width=110,height=40)
    ft = tkFont.Font(family='Lucida Sans',size=13)
    FileLabel["font"] = ft
    ButtonFile = Button(root,text="Upload File",command=read_file)
    ButtonFile.place(x=120,y=200,width=200,height=30)

    #Train Button
    ButtonTrain = Button(root,text="Train",command=change_train)
    ButtonTrain.place(x=350,y=270,width=200,height=30)
    
    #Back Button
    ButtonBack = Button(root, text="Back", command=back_train)
    ButtonBack.place(x=400,y=350,width=100,height=30)
    

def test_f():
    global ButtonFolder, QuestionLabel, FolderLabel, ButtonFolder, ButtonBack, clicked, ButtonTest
    root.geometry("900x700")

    #Title Label
    TitleLabel = Label(root,text="Code Grader")
    ft = tkFont.Font(family='Copperplate',size=22)
    TitleLabel["font"] = ft
    TitleLabel.place(x=350,y=15,width=200,height=35)

    #Select Question
    QuestionLabel = Label(root,text='Select Question :')
    QuestionLabel.place(x=0,y=68,width=110,height=40)
    ft = tkFont.Font(family='Lucida Sans',size=13)
    QuestionLabel["font"] = ft
    questions = read_questionFile()
    clicked = StringVar()
    clicked.set("Questions")
    drop = OptionMenu(root,clicked,*questions,command=get_model)
    drop.size
    drop.place(x=110,y=70,width=770,height=40)

    #Select Folder
    FolderLabel = Label(root,text='Select Folder :')
    FolderLabel.place(x=0,y=130,width=95,height=40)
    ft = tkFont.Font(family='Lucida Sans',size=13)
    FolderLabel["font"] = ft
    ButtonFolder = Button(root,text="Upload Folder",command=read_folder)
    ButtonFolder.place(x=110,y=137,width=200,height=30)
    
    #Train Button
    ButtonTest = Button(root,text="Grade",command=change_test)
    ButtonTest.place(x=350,y=200,width=200,height=30)
    
    #Back Button
    ButtonBack = Button(root, text="Back", command=back_test)
    ButtonBack.place(x=400,y=650,width=100,height=30)
    

  
    
def root_f():
    global TitleLabel, Button_test_frame, Button_train_frame, TitleLabelS
    root.title("Automated Code Grader")
    root.geometry("500x300")

    #Title Label
    TitleLabel = Label(root,text="AUTOMATED CODE GRADER")
    ft = tkFont.Font(family='Copperplate',size=22)
    TitleLabel["font"] = ft
    TitleLabel.place(x=10,y=15,width=500,height=65)

    #Select Question
    TitleLabelS = Label(root,text="Do you want to Grade the codes or train a new Model")
    ft = tkFont.Font(family='Copperplate',size=15)
    TitleLabelS["font"] = ft
    TitleLabelS.place(x=5,y=70,width=500,height=65)

    #Select Folder
    Button_test_frame = Button(root,text="Grade Codes",command=kill_test)
    Button_test_frame.place(x=150,y=150,width=200,height=30)

    #Train Button
    Button_train_frame = Button(root,text="Train Model",command=kill_train)
    Button_train_frame.place(x=150,y=200,width=200,height=30)

# %%
if __name__ == "__main__":
    root = Tk()
    root_f()
    root.mainloop()
# Out:
# Extracting paths from data set...
# Finished extracting paths from data set
# Calculating lines
# N: 833
# Extracting samples to raw files.
# Done extracting samples to raw files.
# Creating histograms from the training data
# Done creating histograms...sending to code2vec for preprocessing
# File: /Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/data/Codes_embeddings/Codes_embeddings.data.raw.txt
# Average total contexts: 421.375
# Average final (after sampling) contexts: 199.5216346153846
# Total examples: 832
# Empty examples: 1
# Max number of contexts per word: 3794
# {'': 833}
# Dictionaries saved to: /Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/data/Codes_embeddings/Codes_embeddings.dict.c2v
# SSSSTTTTTTAAAAAAARRRRRRTTTTTTTT tensor([[214, 137, 122,  ..., 122, 137, 137],
#         [122,  12, 214,  ..., 213,   6, 213],
#         [122, 212, 223,  ..., 221,  36, 213],
#         ...,
#         [198, 122,  63,  ..., 198, 212, 122],
#         [ 63, 223,  26,  ..., 122,   6, 122],
#         [120, 122, 120,  ...,   6, 122, 122]])
# length 512
# Traceback (most recent call last):
#   File "test.py", line 83, in <module>
#     main()
#   File "test.py", line 63, in main
#     code, y_pred = model(start.to(DEVICE), path.to(DEVICE), end.to(DEVICE))
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/model_implementation.py", line 75, in forward
#     start_embedding = self.values_embedding(starts)
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/modules/sparse.py", line 160, in forward
#     self.norm_type, self.scale_grad_by_freq, self.sparse)
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/functional.py", line 2044, in embedding
#     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
# IndexError: index out of range in self
# Extracting paths from data set...
# Finished extracting paths from data set
# Calculating lines
# N: 833
# Extracting samples to raw files.
# Done extracting samples to raw files.
# Creating histograms from the training data
# Done creating histograms...sending to code2vec for preprocessing
# File: /Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/data/Codes_embeddings/Codes_embeddings.data.raw.txt
# Average total contexts: 421.375
# Average final (after sampling) contexts: 199.5216346153846
# Total examples: 832
# Empty examples: 1
# Max number of contexts per word: 3794
# {'': 833}
# Dictionaries saved to: /Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/data/Codes_embeddings/Codes_embeddings.dict.c2v
# SSSSTTTTTTAAAAAAARRRRRRTTTTTTTT tensor([[ 12, 126, 122,  ..., 122, 126, 198],
#         [122, 120, 120,  ..., 223, 120, 120],
#         [122,   5, 120,  ..., 120, 120,  70],
#         ...,
#         [161, 161, 120,  ..., 153, 163, 153],
#         [  5, 198, 122,  ..., 223, 120, 215],
#         [198,  12, 212,  ..., 122,  43,  70]])
# length 218
# Traceback (most recent call last):
#   File "test.py", line 83, in <module>
#     main()
#   File "test.py", line 63, in main
#     code, y_pred = model(start.to(DEVICE), path.to(DEVICE), end.to(DEVICE))
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/model_implementation.py", line 75, in forward
#     start_embedding = self.values_embedding(starts)
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/modules/sparse.py", line 160, in forward
#     self.norm_type, self.scale_grad_by_freq, self.sparse)
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/functional.py", line 2044, in embedding
#     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
# IndexError: index out of range in self
# Extracting paths from data set...
# Finished extracting paths from data set
# Calculating lines
# N: 833
# Extracting samples to raw files.
# Done extracting samples to raw files.
# Creating histograms from the training data
# Done creating histograms...sending to code2vec for preprocessing
# File: /Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/data/Codes_embeddings/Codes_embeddings.data.raw.txt
# Average total contexts: 421.375
# Average final (after sampling) contexts: 199.5216346153846
# Total examples: 832
# Empty examples: 1
# Max number of contexts per word: 3794
# {'': 833}
# Dictionaries saved to: /Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/data/Codes_embeddings/Codes_embeddings.dict.c2v
# SSSSTTTTTTAAAAAAARRRRRRTTTTTTTT tensor([[214, 114, 120,  ..., 117, 120, 117],
#         [198, 126, 122,  ..., 198, 124, 124],
#         [ 36, 124, 124,  ..., 124, 120, 122],
#         ...,
#         [223,  19, 223,  ..., 223,  29,  29],
#         [122, 198,   6,  ...,  61, 122, 124],
#         [ 36, 215, 122,  ..., 120, 223, 212]])
# length 218
# Traceback (most recent call last):
#   File "test.py", line 83, in <module>
#     main()
#   File "test.py", line 63, in main
#     code, y_pred = model(start.to(DEVICE), path.to(DEVICE), end.to(DEVICE))
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/model_implementation.py", line 75, in forward
#     start_embedding = self.values_embedding(starts)
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/modules/sparse.py", line 160, in forward
#     self.norm_type, self.scale_grad_by_freq, self.sparse)
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/functional.py", line 2044, in embedding
#     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
# IndexError: index out of range in self
# Extracting paths from data set...
# Finished extracting paths from data set
# Calculating lines
# N: 833
# Extracting samples to raw files.
# Done extracting samples to raw files.
# Creating histograms from the training data
# Done creating histograms...sending to code2vec for preprocessing
# File: /Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/data/Codes_embeddings/Codes_embeddings.data.raw.txt
# Average total contexts: 421.375
# Average final (after sampling) contexts: 199.5216346153846
# Total examples: 832
# Empty examples: 1
# Max number of contexts per word: 3794
# {'': 833}
# Dictionaries saved to: /Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/data/Codes_embeddings/Codes_embeddings.dict.c2v
# code2vec_model() selffffff
# SSSSTTTTTTAAAAAAARRRRRRTTTTTTTT tensor([[122, 120, 120,  ..., 214, 122, 122],
#         [ 69,  63, 197,  ...,   4,  69,  43],
#         [122,   5,  13,  ..., 120,  13, 122],
#         ...,
#         [122, 212,  12,  ..., 122, 122, 120],
#         [212, 120, 122,  ...,  63, 224, 120],
#         [126, 124, 124,  ..., 126, 122, 122]])
# length 218
# Traceback (most recent call last):
#   File "test.py", line 83, in <module>
#     main()
#   File "test.py", line 63, in main
#     code, y_pred = model(start.to(DEVICE), path.to(DEVICE), end.to(DEVICE))
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/model_implementation.py", line 76, in forward
#     start_embedding = self.values_embedding(starts)
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/modules/sparse.py", line 160, in forward
#     self.norm_type, self.scale_grad_by_freq, self.sparse)
#   File "/Users/unaissiddiqui/opt/anaconda3/envs/fyp/lib/python3.7/site-packages/torch/nn/functional.py", line 2044, in embedding
#     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
# IndexError: index out of range in self

# %%
data = pd.read_csv("/Users/unaissiddiqui/Desktop/Fyp/Automated_Code_Grader/Values.csv")
values_vocab_size = data[data['ID']==dataset_name]['word2idx'].values[0]
paths_vocab_size = data[data['ID']==dataset_name]['path2idx'].values[0]
labels_num = data[data['ID']==dataset_name]['target2idx'].values[0]
cmd = f"python test.py {str(model_number)} {values_vocab_size} {paths_vocab_size} {labels_num}"
print(cmd)
# Out:
# python test.py 6481076 218 10546 6

# %%
import numpy as np
# import random
data_1 = np.random.normal(100, 10, 200)
data_1
# Out:
# array([ 94.84894142,  78.78932897, 110.90284897,  92.04710638,
#        103.99861848,  95.71090969, 107.27388334,  92.35539469,
#         99.76212683,  95.546986  ,  91.54853363,  89.99516035,
#         93.42580497,  89.40033302,  89.31161231,  98.27579038,
#         78.03486945,  89.1061361 , 104.57985083,  97.87386987,
#         91.87976105,  92.14773201,  85.02923956,  98.031821  ,
#         80.90399487,  98.57208583,  96.20065659,  91.19206305,
#         94.20488738, 104.62442378,  98.37049367,  96.06656052,
#        107.66635429,  96.11384528, 116.66206652, 118.38728493,
#         99.98716459, 112.94233113, 104.36348361, 100.84610983,
#         94.00952899,  86.87596036,  95.02276373, 108.66581614,
#         97.50644546, 117.7234556 ,  99.2572771 , 103.47301651,
#         93.43889234, 107.03127724, 103.33524819, 112.43702012,
#        108.55984732, 110.82131771,  86.0300717 ,  91.79636769,
#         97.77393661, 104.44152695,  81.3254835 , 110.15306506,
#         87.80304319, 100.22512762, 115.7625837 , 110.4337511 ,
#        104.91801631,  79.75992586, 106.96944714,  96.35800534,
#         91.66328649, 105.58489757,  91.68726791,  84.65561864,
#         91.0216624 ,  96.5686181 , 104.85001433,  95.02885572,
#         99.18973155, 105.86849947,  87.05583355, 104.02786355,
#        117.72911258, 119.51645936,  87.64239889, 103.98345004,
#         86.17389035,  98.7352693 , 109.69135886,  91.09238518,
#        107.80230507,  98.92473584, 100.8625101 , 105.85602752,
#         83.11099411,  98.4385342 ,  98.69863123,  96.95272317,
#         78.13122232,  94.50812511, 105.67349894,  86.28553821,
#         92.60505832, 106.71825903, 120.61878052,  87.07730204,
#        103.7650192 ,  99.98998709,  89.80703205, 103.25494804,
#         90.36010912, 108.41898462, 102.75781893, 106.49938213,
#         99.01405893, 117.14707331,  95.77692194, 121.5889535 ,
#         93.29076556,  84.04845073, 111.15341851, 105.09525674,
#        108.91191363,  79.26494014,  99.63205876,  91.38122053,
#         92.44894077,  91.61019451, 106.02619077,  99.24882681,
#         93.72546304, 100.42935289,  93.69196723,  98.5548921 ,
#         99.91763275,  95.44648696, 102.19547952,  89.6978999 ,
#        106.03479666,  94.02827341, 110.10786911,  89.63363172,
#         85.43076961, 101.28500391,  96.31682672,  93.60665748,
#        111.24211019, 114.99910641, 117.25663499,  99.07861255,
#        106.64746405,  91.13183893,  94.7395962 ,  86.17890914,
#        101.53483991, 102.41925799,  95.52134515,  94.00569454,
#         96.30331226,  96.93966539, 101.26212724,  99.5964139 ,
#        106.19943265,  89.23032261,  95.2709875 ,  78.65534941,
#         92.92111145, 106.42277476, 100.73850877, 109.79862713,
#        109.50525138, 114.70738348, 117.78513939,  97.15198716,
#         99.64634841,  96.01018785, 110.02165524, 117.39880783,
#         91.55932936,  99.47165155,  86.04129176,  91.56753914,
#         82.8022663 ,  95.52893875,  96.59725644,  97.17411481,
#        103.86132808,  94.54746533, 112.17817826,  84.32763708,
#         91.08561739,  93.15646213,  99.27327974,  90.00553578,
#        104.9650086 , 104.07259937,  97.89075701,  97.73941145,
#         92.05125794,  98.50586268, 108.88140215,  96.09827472])
